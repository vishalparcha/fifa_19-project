# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
sns.set_style('whitegrid')
import pandas as pd
fifa_19 = pd.read_csv(r'C:\Users\AMIT\Desktop\DataScience_01Mar2020\ClassVideos\data.csv',
                index_col=0)

# %%
fifa_19.head(10)
# Out:
#        ID               Name  Age  \
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
# 2  190871          Neymar Jr   26
# 3  193080             De Gea   27
# 4  192985       K. De Bruyne   27
# 5  183277          E. Hazard   27
# 6  177003          L. Modrić   32
# 7  176580          L. Suárez   31
# 8  155862       Sergio Ramos   32
# 9  200389           J. Oblak   25
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# 5  https://cdn.sofifa.org/players/4/19/183277.png     Belgium
# 6  https://cdn.sofifa.org/players/4/19/177003.png     Croatia
# 7  https://cdn.sofifa.org/players/4/19/176580.png     Uruguay
# ...

# %%
# !head fifa_19.csv
# Out:
# 'head' is not recognized as an internal or external command,
# operable program or batch file.

# %%
new_dataset=fifa_19[['Name', 'Overall','Potential', 'Composure','Marking','StandingTackle','SlidingTackle','GKDiving','GKHandling','GKKicking','GKPositioning','GKReflexes']]
print(new_dataset)
# Out:
#                      Name  Overall  Potential  Composure  Marking  \
# 0                L. Messi       94         94       96.0     33.0
# 1       Cristiano Ronaldo       94         94       95.0     28.0
# 2               Neymar Jr       92         93       94.0     27.0
# 3                  De Gea       91         93       68.0     15.0
# 4            K. De Bruyne       91         92       88.0     68.0
# ...                   ...      ...        ...        ...      ...
# 18202        J. Lundstram       47         65       45.0     40.0
# 18203  N. Christoffersson       47         63       42.0     22.0
# 18204           B. Worman       47         67       41.0     32.0
# 18205      D. Walker-Rice       47         66       46.0     20.0
# 18206           G. Nugent       46         66       43.0     40.0
#
#        StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 0                28.0           26.0       6.0        11.0       15.0
# ...

# %%
b = fifa_19.transpose()
print(b)
# Out:
#                                                          0      \
# ID                                                      158023
# Name                                                  L. Messi
# Age                                                         31
# Photo           https://cdn.sofifa.org/players/4/19/158023.png
# Nationality                                          Argentina
# ...                                                        ...
# GKHandling                                                  11
# GKKicking                                                   15
# GKPositioning                                               14
# GKReflexes                                                   8
# Release Clause                                         €226.5M
#
#                                                         1      \
# ID                                                      20801
# Name                                        Cristiano Ronaldo
# ...

# %%
#sns.barplot(x='Name',y='Potential',data=fifa_19)

# %%
#desc fifa_19

# %%
new_dataset=fifa_19[['Name', 'Overall','Potential', 'Composure','Marking','StandingTackle','SlidingTackle','GKDiving','GKHandling','GKKicking','GKPositioning','GKReflexes']]
print(new_dataset)
# Out:
#                      Name  Overall  Potential  Composure  Marking  \
# 0                L. Messi       94         94       96.0     33.0
# 1       Cristiano Ronaldo       94         94       95.0     28.0
# 2               Neymar Jr       92         93       94.0     27.0
# 3                  De Gea       91         93       68.0     15.0
# 4            K. De Bruyne       91         92       88.0     68.0
# ...                   ...      ...        ...        ...      ...
# 18202        J. Lundstram       47         65       45.0     40.0
# 18203  N. Christoffersson       47         63       42.0     22.0
# 18204           B. Worman       47         67       41.0     32.0
# 18205      D. Walker-Rice       47         66       46.0     20.0
# 18206           G. Nugent       46         66       43.0     40.0
#
#        StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 0                28.0           26.0       6.0        11.0       15.0
# ...

# %%
fifa_19.head()
# Out:
#        ID               Name  Age  \
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
# 2  190871          Neymar Jr   26
# 3  193080             De Gea   27
# 4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
# ...

# %%
Additional_coloumn=new_dataset.max(axis=1)

print(Additional_coloumn)
# Out:
# 0        96.0
# 1        95.0
# 2        94.0
# 3        94.0
# 4        92.0
#          ...
# 18202    65.0
# 18203    63.0
# 18204    67.0
# 18205    66.0
# 18206    66.0
# Length: 18207, dtype: float64

# %%
vishal= pd.DataFrame(new_dataset) 
Additional_coloumn=new_dataset.max(axis=1)
vishal['total'] = Additional_coloumn 
vishal.sort_values('total')

print(vishal)
# Out:
#                      Name  Overall  Potential  Composure  Marking  \
# 0                L. Messi       94         94       96.0     33.0
# 1       Cristiano Ronaldo       94         94       95.0     28.0
# 2               Neymar Jr       92         93       94.0     27.0
# 3                  De Gea       91         93       68.0     15.0
# 4            K. De Bruyne       91         92       88.0     68.0
# ...                   ...      ...        ...        ...      ...
# 18202        J. Lundstram       47         65       45.0     40.0
# 18203  N. Christoffersson       47         63       42.0     22.0
# 18204           B. Worman       47         67       41.0     32.0
# 18205      D. Walker-Rice       47         66       46.0     20.0
# 18206           G. Nugent       46         66       43.0     40.0
#
#        StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 0                28.0           26.0       6.0        11.0       15.0
# ...

# %% [markdown]
# # Best player in ovarall rating

# %%
#vishal.plot(x='Name', y='total')

# %%
vishal.plot(x='Name', y='total')

# %% [markdown]
# ## Average rating of player

# %%
fifa_19.describe()
# Out:
#                   ID           Age       Overall     Potential       Special  \
# count   18207.000000  18207.000000  18207.000000  18207.000000  18207.000000
# mean   214298.338606     25.122206     66.238699     71.307299   1597.809908
# std     29965.244204      4.669943      6.908930      6.136496    272.586016
# min        16.000000     16.000000     46.000000     48.000000    731.000000
# 25%    200315.500000     21.000000     62.000000     67.000000   1457.000000
# 50%    221759.000000     25.000000     66.000000     71.000000   1635.000000
# 75%    236529.500000     28.000000     71.000000     75.000000   1787.000000
# max    246620.000000     45.000000     94.000000     95.000000   2346.000000
#
#        International Reputation     Weak Foot   Skill Moves  Jersey Number  \
# count              18159.000000  18159.000000  18159.000000   18147.000000
# mean                   1.113222      2.947299      2.361308      19.546096
# ...

# %%
vishal.mean()

vishal.mean().plot(kind='bar')

# %%
import numpy as np
import pandas as pd

# %%
fifa_19.head(10)
# Out:
#        ID               Name  Age  \
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
# 2  190871          Neymar Jr   26
# 3  193080             De Gea   27
# 4  192985       K. De Bruyne   27
# 5  183277          E. Hazard   27
# 6  177003          L. Modrić   32
# 7  176580          L. Suárez   31
# 8  155862       Sergio Ramos   32
# 9  200389           J. Oblak   25
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# 5  https://cdn.sofifa.org/players/4/19/183277.png     Belgium
# 6  https://cdn.sofifa.org/players/4/19/177003.png     Croatia
# 7  https://cdn.sofifa.org/players/4/19/176580.png     Uruguay
# ...

# %%
fifa_19.agg({'Overall': 'mean',
          'Acceleration' : 'mean',
          'ShotPower' : 'mean'})

#.sort_values('Overall', ascending=False).head(10)
# Out:
# Overall         66.238699
# Acceleration    64.614076
# ShotPower       55.460047
# dtype: float64

# %%
fifa_19.head(10)
# Out:
#        ID               Name  Age  \
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
# 2  190871          Neymar Jr   26
# 3  193080             De Gea   27
# 4  192985       K. De Bruyne   27
# 5  183277          E. Hazard   27
# 6  177003          L. Modrić   32
# 7  176580          L. Suárez   31
# 8  155862       Sergio Ramos   32
# 9  200389           J. Oblak   25
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# 5  https://cdn.sofifa.org/players/4/19/183277.png     Belgium
# 6  https://cdn.sofifa.org/players/4/19/177003.png     Croatia
# 7  https://cdn.sofifa.org/players/4/19/176580.png     Uruguay
# ...

# %%
ratings = fifa_19[["Nationality", "Overall"]]
ratings.groupby(["Nationality"]).mean().sort_values(by="Overall", ascending=False).head(10)
# Out:
#                         Overall
# Nationality
# United Arab Emirates  77.000000
# Central African Rep.  73.333333
# Israel                72.142857
# Dominican Republic    72.000000
# São Tomé & Príncipe   72.000000
# Oman                  72.000000
# Cape Verde            71.631579
# Portugal              71.344720
# Togo                  71.333333
# Brazil                71.251511

# %%
sns.jointplot(x='Overall', y='Nationality',data=ratings , kind='scatter')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-ba0cd7aeeacf> in <module>
# ----> 1 sns.jointplot(x='Overall', y='Nationality',data=ratings , kind='scatter')
#
# ~\anaconda3\lib\site-packages\seaborn\axisgrid.py in jointplot(x, y, data, kind, stat_func, color, height, ratio, space, dropna, xlim, ylim, joint_kws, marginal_kws, annot_kws, **kwargs)
#    2299         marginal_kws.setdefault("kde", False)
#    2300         marginal_kws.setdefault("color", color)
# -> 2301         grid.plot_marginals(distplot, **marginal_kws)
#    2302
#    2303     elif kind.startswith("hex"):
#
# ~\anaconda3\lib\site-packages\seaborn\axisgrid.py in plot_marginals(self, func, **kwargs)
#    1812         kwargs["vertical"] = True
#    1813         plt.sca(self.ax_marg_y)
# -> 1814         func(self.y, **kwargs)
#    1815
#    1816         return self
#
# ...

# %% [markdown]
# # Distribution of players nationalities

# %%
dis = fifa_19[["Nationality", "Name"]]
dis.groupby(["Nationality"])
dis
# Out:
#       Nationality                Name
# 0       Argentina            L. Messi
# 1        Portugal   Cristiano Ronaldo
# 2          Brazil           Neymar Jr
# 3           Spain              De Gea
# 4         Belgium        K. De Bruyne
# ...           ...                 ...
# 18202     England        J. Lundstram
# 18203      Sweden  N. Christoffersson
# 18204     England           B. Worman
# 18205     England      D. Walker-Rice
# 18206     England           G. Nugent
#
# [18207 rows x 2 columns]

# %%
sns.countplot(x='Nationality',data=dis)

# %% [markdown]
# ## Distribution of players values

# %%
fifa_19.head(10)
# Out:
#        ID               Name  Age  \
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
# 2  190871          Neymar Jr   26
# 3  193080             De Gea   27
# 4  192985       K. De Bruyne   27
# 5  183277          E. Hazard   27
# 6  177003          L. Modrić   32
# 7  176580          L. Suárez   31
# 8  155862       Sergio Ramos   32
# 9  200389           J. Oblak   25
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# 5  https://cdn.sofifa.org/players/4/19/183277.png     Belgium
# 6  https://cdn.sofifa.org/players/4/19/177003.png     Croatia
# 7  https://cdn.sofifa.org/players/4/19/176580.png     Uruguay
# ...

# %%
val = fifa_19[["Value", "Name"]]
val.groupby(["Value"])
val
# Out:
#          Value                Name
# 0      €110.5M            L. Messi
# 1         €77M   Cristiano Ronaldo
# 2      €118.5M           Neymar Jr
# 3         €72M              De Gea
# 4        €102M        K. De Bruyne
# ...        ...                 ...
# 18202     €60K        J. Lundstram
# 18203     €60K  N. Christoffersson
# 18204     €60K           B. Worman
# 18205     €60K      D. Walker-Rice
# 18206     €60K           G. Nugent
#
# [18207 rows x 2 columns]

# %%
import numpy as np

# %%
plt.hist(val['Value'], facecolor='cyan',edgecolor='blue',bins=10)
plt.tight_layout()

# %% [markdown]
# ## Total number of right foot and left foot players

# %%
fifa_19.head(10)
# Out:
#        ID               Name  Age  \
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
# 2  190871          Neymar Jr   26
# 3  193080             De Gea   27
# 4  192985       K. De Bruyne   27
# 5  183277          E. Hazard   27
# 6  177003          L. Modrić   32
# 7  176580          L. Suárez   31
# 8  155862       Sergio Ramos   32
# 9  200389           J. Oblak   25
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# 5  https://cdn.sofifa.org/players/4/19/183277.png     Belgium
# 6  https://cdn.sofifa.org/players/4/19/177003.png     Croatia
# 7  https://cdn.sofifa.org/players/4/19/176580.png     Uruguay
# ...

# %%
df_foot = fifa_19[['ID', 'Name', 'Age', 'Nationality', 'Preferred Foot', 'Weak Foot']]
df_foot.head(10)
# Out:
#        ID               Name  Age Nationality Preferred Foot  Weak Foot
# 0  158023           L. Messi   31   Argentina           Left        4.0
# 1   20801  Cristiano Ronaldo   33    Portugal          Right        4.0
# 2  190871          Neymar Jr   26      Brazil          Right        5.0
# 3  193080             De Gea   27       Spain          Right        3.0
# 4  192985       K. De Bruyne   27     Belgium          Right        5.0
# 5  183277          E. Hazard   27     Belgium          Right        4.0
# 6  177003          L. Modrić   32     Croatia          Right        4.0
# 7  176580          L. Suárez   31     Uruguay          Right        4.0
# 8  155862       Sergio Ramos   32       Spain          Right        3.0
# 9  200389           J. Oblak   25    Slovenia          Right        3.0

# %%
f = df_foot['Preferred Foot'].value_counts(dropna=True)
pd.DataFrame(f)
# Out:
#        Preferred Foot
# Right           13948
# Left             4211

# %%
#plt.hist(['f'], facecolor='cyan',edgecolor='blue',bins=10)
#f.plot()
#sns.barplot(x='Preferred Foot',y='Name',data=df_foot)
df_foot.head(10)
# Out:
#        ID               Name  Age Nationality Preferred Foot  Weak Foot
# 0  158023           L. Messi   31   Argentina           Left        4.0
# 1   20801  Cristiano Ronaldo   33    Portugal          Right        4.0
# 2  190871          Neymar Jr   26      Brazil          Right        5.0
# 3  193080             De Gea   27       Spain          Right        3.0
# 4  192985       K. De Bruyne   27     Belgium          Right        5.0
# 5  183277          E. Hazard   27     Belgium          Right        4.0
# 6  177003          L. Modrić   32     Croatia          Right        4.0
# 7  176580          L. Suárez   31     Uruguay          Right        4.0
# 8  155862       Sergio Ramos   32       Spain          Right        3.0
# 9  200389           J. Oblak   25    Slovenia          Right        3.0

# %%
pd.DataFrame(f)
# Out:
#        Preferred Foot
# Right           13948
# Left             4211

# %%
sns.countplot(x='Preferred Foot',data=df_foot)

# %% [markdown]
# ## Names of players and their age

# %%
fifa_19.head(10)
# Out:
#        ID               Name  Age  \
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
# 2  190871          Neymar Jr   26
# 3  193080             De Gea   27
# 4  192985       K. De Bruyne   27
# 5  183277          E. Hazard   27
# 6  177003          L. Modrić   32
# 7  176580          L. Suárez   31
# 8  155862       Sergio Ramos   32
# 9  200389           J. Oblak   25
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# 5  https://cdn.sofifa.org/players/4/19/183277.png     Belgium
# 6  https://cdn.sofifa.org/players/4/19/177003.png     Croatia
# 7  https://cdn.sofifa.org/players/4/19/176580.png     Uruguay
# ...

# %%
df_age = fifa_19[['Name', 'Age']]
df_age.iloc[0:10]
#df_age.head(10)
# Out:
#                 Name  Age
# 0           L. Messi   31
# 1  Cristiano Ronaldo   33
# 2          Neymar Jr   26
# 3             De Gea   27
# 4       K. De Bruyne   27
# 5          E. Hazard   27
# 6          L. Modrić   32
# 7          L. Suárez   31
# 8       Sergio Ramos   32
# 9           J. Oblak   25

# %%
df_age.iloc[0:11].plot(x='Name')

# %% [markdown]
# ### Name of players and their wages

# %%
df_wages=fifa_19[['Name','Wage']]
df_wages.iloc[0:12]
# Out:
#                  Name   Wage
# 0            L. Messi  €565K
# 1   Cristiano Ronaldo  €405K
# 2           Neymar Jr  €290K
# 3              De Gea  €260K
# 4        K. De Bruyne  €355K
# 5           E. Hazard  €340K
# 6           L. Modrić  €420K
# 7           L. Suárez  €455K
# 8        Sergio Ramos  €380K
# 9            J. Oblak   €94K
# 10     R. Lewandowski  €205K
# 11           T. Kroos  €355K

# %%
import plotly.graph_objects as go

# %%
df_wages.iloc[0:5].plot(kind='scatter',x='Name',y='Wage')

# %% [markdown]
# ## Top 10 players according to value

# %%
fifa_19.head(10)
# Out:
#        ID               Name  Age  \
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
# 2  190871          Neymar Jr   26
# 3  193080             De Gea   27
# 4  192985       K. De Bruyne   27
# 5  183277          E. Hazard   27
# 6  177003          L. Modrić   32
# 7  176580          L. Suárez   31
# 8  155862       Sergio Ramos   32
# 9  200389           J. Oblak   25
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# 5  https://cdn.sofifa.org/players/4/19/183277.png     Belgium
# 6  https://cdn.sofifa.org/players/4/19/177003.png     Croatia
# 7  https://cdn.sofifa.org/players/4/19/176580.png     Uruguay
# ...

# %%
df_value = fifa_19[['Name','Value']]
df_value.iloc[0:11]
# Out:
#                  Name    Value
# 0            L. Messi  €110.5M
# 1   Cristiano Ronaldo     €77M
# 2           Neymar Jr  €118.5M
# 3              De Gea     €72M
# 4        K. De Bruyne    €102M
# 5           E. Hazard     €93M
# 6           L. Modrić     €67M
# 7           L. Suárez     €80M
# 8        Sergio Ramos     €51M
# 9            J. Oblak     €68M
# 10     R. Lewandowski     €77M

# %%
df_value.iloc[0:11].plot(x='Name' ,y='Value', kind='scatter')

# %% [markdown]
# ## Top 10 potential players

# %%
fifa_19.head(10)
# Out:
#        ID               Name  Age  \
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
# 2  190871          Neymar Jr   26
# 3  193080             De Gea   27
# 4  192985       K. De Bruyne   27
# 5  183277          E. Hazard   27
# 6  177003          L. Modrić   32
# 7  176580          L. Suárez   31
# 8  155862       Sergio Ramos   32
# 9  200389           J. Oblak   25
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# 5  https://cdn.sofifa.org/players/4/19/183277.png     Belgium
# 6  https://cdn.sofifa.org/players/4/19/177003.png     Croatia
# 7  https://cdn.sofifa.org/players/4/19/176580.png     Uruguay
# ...

# %%
df_p=fifa_19[['Name' ,'Potential']]
df_p.iloc[0:11]
# Out:
#                  Name  Potential
# 0            L. Messi         94
# 1   Cristiano Ronaldo         94
# 2           Neymar Jr         93
# 3              De Gea         93
# 4        K. De Bruyne         92
# 5           E. Hazard         91
# 6           L. Modrić         91
# 7           L. Suárez         91
# 8        Sergio Ramos         91
# 9            J. Oblak         93
# 10     R. Lewandowski         90

# %%
df_p.iloc[0:11].plot('Name')
